# %%
# %pwd
# Out:
# 'C:\\Users\\Deidra\\Coursera-IBM\\9 CAPSTONE SUBMISSION'

# %%
import pandas as pd

# %%
data = pd.read_csv('Data-Collisions.csv')
# Out:
# C:\Users\Deidra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.iloc[:3,20:40]
# Out:
#                   INCDATE                 INCDTTM  \
# 0  2013/03/27 00:00:00+00    3/27/2013 2:54:00 PM
# 1  2006/12/20 00:00:00+00   12/20/2006 6:55:00 PM
# 2  2004/11/18 00:00:00+00  11/18/2004 10:20:00 AM
#
#                               JUNCTIONTYPE  SDOT_COLCODE  \
# 0   At Intersection (intersection related)            11
# 1  Mid-Block (not related to intersection)            16
# 2  Mid-Block (not related to intersection)            14
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...            NaN         N
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...            NaN         0
# 2       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END            NaN         0
#
#     WEATHER ROADCOND                LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM  \
# 0  Overcast      Wet                 Daylight           NaN         NaN
# ...

# %%
data.columns
# Out:
# Index(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
#        'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'],
#       dtype='object')

# %%
df = data.filter(items= ['SEVERITYCODE', 'X', 'Y', 'INCKEY', 'ADDRTYPE', 'LOCATION', 'SEVERITYDESC', 'COLLISIONTYPE',
       'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
       'INCDTTM', 'JUNCTIONTYPE','INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
       'PEDROWNOTGRNT', 'SPEEDING', 'HITPARKEDCAR',  'ST_COLCODE','SDOT_COLDESC'])
df.head(3)
# Out:
#    SEVERITYCODE           X          Y  INCKEY      ADDRTYPE  \
# 0             2 -122.323148  47.703140    1307  Intersection
# 1             1 -122.347294  47.647172   52200         Block
# 2             1 -122.334540  47.607871   26700         Block
#
#                                       LOCATION  \
# 0                   5TH AVE NE AND NE 103RD ST
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  ...  \
# 0                Injury Collision        Angles            2         0  ...
# 1  Property Damage Only Collision     Sideswipe            2         0  ...
# 2  Property Damage Only Collision    Parked Car            4         0  ...
#
#    INATTENTIONIND  UNDERINFL   WEATHER ROADCOND                LIGHTCOND  \
# 0             NaN          N  Overcast      Wet                 Daylight
# ...

# %%
df.shape
# Out:
# (194673, 25)

# %%
df.iloc[:5, :10]
# Out:
#    SEVERITYCODE           X          Y  INCKEY      ADDRTYPE  \
# 0             2 -122.323148  47.703140    1307  Intersection
# 1             1 -122.347294  47.647172   52200         Block
# 2             1 -122.334540  47.607871   26700         Block
# 3             1 -122.334803  47.604803    1144         Block
# 4             2 -122.306426  47.545739   17700  Intersection
#
#                                       LOCATION  \
# 0                   5TH AVE NE AND NE 103RD ST
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST
# 4              SWIFT AVE S AND SWIFT AV OFF RP
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT
# 0                Injury Collision        Angles            2         0
# 1  Property Damage Only Collision     Sideswipe            2         0
# 2  Property Damage Only Collision    Parked Car            4         0
# ...

# %%
df.iloc[:5, 10:20]
# Out:
#    PEDCYLCOUNT  VEHCOUNT                 INCDATE                 INCDTTM  \
# 0            0         2  2013/03/27 00:00:00+00    3/27/2013 2:54:00 PM
# 1            0         2  2006/12/20 00:00:00+00   12/20/2006 6:55:00 PM
# 2            0         3  2004/11/18 00:00:00+00  11/18/2004 10:20:00 AM
# 3            0         3  2013/03/29 00:00:00+00    3/29/2013 9:26:00 AM
# 4            0         2  2004/01/28 00:00:00+00    1/28/2004 8:04:00 AM
#
#                               JUNCTIONTYPE INATTENTIONIND UNDERINFL   WEATHER  \
# 0   At Intersection (intersection related)            NaN         N  Overcast
# 1  Mid-Block (not related to intersection)            NaN         0   Raining
# 2  Mid-Block (not related to intersection)            NaN         0  Overcast
# 3  Mid-Block (not related to intersection)            NaN         N     Clear
# 4   At Intersection (intersection related)            NaN         0   Raining
#
#   ROADCOND                LIGHTCOND
# ...

# %%
df.iloc[:5, 20:30]
# Out:
#   PEDROWNOTGRNT SPEEDING HITPARKEDCAR ST_COLCODE  \
# 0           NaN      NaN            N         10
# 1           NaN      NaN            N         11
# 2           NaN      NaN            N         32
# 3           NaN      NaN            N         23
# 4           NaN      NaN            N         10
#
#                                         SDOT_COLDESC
# 0  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...
# 1  MOTOR VEHICLE STRUCK MOTOR VEHICLE, LEFT SIDE ...
# 2       MOTOR VEHICLE STRUCK MOTOR VEHICLE, REAR END
# 3  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...
# 4  MOTOR VEHICLE STRUCK MOTOR VEHICLE, FRONT END ...

# %%
#'Injury Collision' (2), 'Property Damage Only Collision' (1)
df['SEVERITYCODE'].unique()
#df['SEVERITYDESC'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
#must be unique for each row
df[df.duplicated(['INCKEY'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [SEVERITYCODE, X, Y, INCKEY, ADDRTYPE, LOCATION, SEVERITYDESC, COLLISIONTYPE, PERSONCOUNT, PEDCOUNT, PEDCYLCOUNT, VEHCOUNT, INCDATE, INCDTTM, JUNCTIONTYPE, INATTENTIONIND, UNDERINFL, WEATHER, ROADCOND, LIGHTCOND, PEDROWNOTGRNT, SPEEDING, SEGLANEKEY, CROSSWALKKEY, HITPARKEDCAR]
# Index: []
#
# [0 rows x 25 columns]

# %%
df['ADDRTYPE'].unique()
# Out:
# array(['Intersection', 'Block', 'Alley', nan], dtype=object)

# %%
df['VEHCOUNT'].unique()
# Out:
# array([ 2,  3,  1,  0,  4,  7,  5,  6,  8, 11,  9, 10, 12], dtype=int64)

# %%
df['COLLISIONTYPE'].unique()
# Out:
# array(['Angles', 'Sideswipe', 'Parked Car', 'Other', 'Cycles',
#        'Rear Ended', 'Head On', nan, 'Left Turn', 'Pedestrian',
#        'Right Turn'], dtype=object)

# %%
df['PEDCYLCOUNT'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df['PEDCOUNT'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
#human error
df['INATTENTIONIND'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
#human error
df['UNDERINFL'].unique()
# Out:
# array(['N', '0', nan, '1', 'Y'], dtype=object)

# %%
df['HITPARKEDCAR'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['PERSONCOUNT'].unique()
# Out:
# array([ 2,  4,  3,  0,  1,  5,  6, 16,  8,  7, 11,  9, 12, 17, 26, 22, 10,
#        37, 13, 36, 28, 14, 53, 19, 30, 29, 23, 44, 15, 32, 21, 41, 27, 20,
#        35, 43, 81, 18, 25, 48, 24, 34, 57, 39, 47, 54, 31], dtype=int64)

# %%
df['LOCATION'].unique()
# Out:
# array(['5TH AVE NE AND NE 103RD ST',
#        'AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N',
#        '4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST', ...,
#        '47TH AVE SW AND SW 98TH ST', 'NE PARK RD AND NE RAVENNA WB BV',
#        'PUGET BLVD SW BETWEEN SW HUDSON ST AND DEAD END 1'], dtype=object)

# %%
df['JUNCTIONTYPE'].unique()
# Out:
# array(['At Intersection (intersection related)',
#        'Mid-Block (not related to intersection)', 'Driveway Junction',
#        'Mid-Block (but intersection related)',
#        'At Intersection (but not related to intersection)', nan,
#        'Unknown', 'Ramp Junction'], dtype=object)

# %%
df['WEATHER'].unique()
# Out:
# array(['Overcast', 'Raining', 'Clear', nan, 'Unknown', 'Other', 'Snowing',
#        'Fog/Smog/Smoke', 'Sleet/Hail/Freezing Rain', 'Blowing Sand/Dirt',
#        'Severe Crosswind', 'Partly Cloudy'], dtype=object)

# %%
df['ROADCOND'].unique()
# Out:
# array(['Wet', 'Dry', nan, 'Unknown', 'Snow/Slush', 'Ice', 'Other',
#        'Sand/Mud/Dirt', 'Standing Water', 'Oil'], dtype=object)

# %%
df['LIGHTCOND'].unique()
# Out:
# array(['Daylight', 'Dark - Street Lights On', 'Dark - No Street Lights',
#        nan, 'Unknown', 'Dusk', 'Dawn', 'Dark - Street Lights Off',
#        'Other', 'Dark - Unknown Lighting'], dtype=object)

# %%
df['PEDROWNOTGRNT'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
df['SPEEDING'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
df['ST_COLCODE'].unique()
# Out:
# array(['10', '11', '32', '23', '5', '22', '14', '30', ' ', '28', '51',
#        '13', '50', '12', '45', '0', '20', '21', '1', '52', '16', '15',
#        '74', '81', '26', '19', '2', '66', '71', '3', '24', '40', '57',
#        '6', '83', '25', '27', '4', '72', '29', '56', '73', '41', '17',
#        '65', '82', '67', '49', '84', '31', '43', '42', '48', '64', '53',
#        32, 50, 15, 10, 14, 20, 13, 22, 51, 11, 28, 12, 52, 21, 0, 19, 30,
#        16, 40, 26, 27, 83, 2, 45, 65, 23, 24, 71, 1, 29, 81, 25, 4, 73,
#        74, 72, 3, 84, 64, 57, 42, 41, 48, 66, 56, 31, 82, 67, '54', '60',
#        53, 43, 87, 54, '87', nan, '7', '8', '85', '88', '18'],
#       dtype=object)

# %%
df[['ST_COLCODE','SDOT_COLDESC']].sort_values(by=['SDOT_COLDESC'])
# Out:
#        ST_COLCODE                                       SDOT_COLDESC
# 57112          50  DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OB...
# 22256          32  DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OB...
# 40306          50  DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OB...
# 11928          50  DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OB...
# 25010          50  DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OB...
# ...           ...                                                ...
# 93784          45                     PEDALCYCLIST STRUCK PEDESTRIAN
# 79413          45                     PEDALCYCLIST STRUCK PEDESTRIAN
# 193153          7                     PEDALCYCLIST STRUCK PEDESTRIAN
# 155585         45                     PEDALCYCLIST STRUCK PEDESTRIAN
# 112000         45                     PEDALCYCLIST STRUCK PEDESTRIAN
#
# [194673 rows x 2 columns]

# %%
df['SDOT_COLDESC'].iloc[22256]
# Out:
# 'DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OBJECT'

# %%
df['SDOT_COLDESC'].iloc[40306]
# Out:
# 'DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OBJECT'

# %%
df['COLLISIONTYPE'] == 'Pedestrian'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 194668    False
# 194669    False
# 194670    False
# 194671    False
# 194672    False
# Name: COLLISIONTYPE, Length: 194673, dtype: bool

# %%
df.loc[(df['COLLISIONTYPE'] == 'Pedestrian')].head(3)
# Out:
#     SEVERITYCODE           X          Y  INCKEY      ADDRTYPE  \
# 71             2 -122.341775  47.615265   41900  Intersection
# 84             2 -122.302233  47.599281  112500  Intersection
# 92             1 -122.320762  47.612963  330954  Intersection
#
#                        LOCATION                    SEVERITYDESC COLLISIONTYPE  \
# 71     5TH AVE AND BLANCHARD ST                Injury Collision    Pedestrian
# 84  23RD AVE S AND S JACKSON ST                Injury Collision    Pedestrian
# 92      BROADWAY AND E UNION ST  Property Damage Only Collision    Pedestrian
#
#     PERSONCOUNT  PEDCOUNT  ...  INATTENTIONIND  UNDERINFL   WEATHER ROADCOND  \
# 71            2         1  ...             NaN          0     Clear      Dry
# 84            2         1  ...             NaN          N     Clear      Dry
# 92            3         1  ...             NaN          N  Overcast      Wet
#
#                   LIGHTCOND PEDROWNOTGRNT SPEEDING HITPARKEDCAR ST_COLCODE  \
# ...

# %%
df.groupby(['SDOT_COLDESC']).count()
# Out:
#                                                     SEVERITYCODE      X  \
# SDOT_COLDESC
# DRIVERLESS VEHICLE RAN OFF ROAD - HIT FIXED OBJECT           107    106
# DRIVERLESS VEHICLE RAN OFF ROAD - NO COLLISION                 1      1
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE FRONT E...           104    102
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE LEFT SI...            53     53
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE LEFT SI...             4      4
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE REAR END              93     91
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE RIGHT S...            12     12
# DRIVERLESS VEHICLE STRUCK MOTOR VEHICLE RIGHT S...             6      6
# DRIVERLESS VEHICLE STRUCK OBJECT IN ROADWAY                    3      3
# DRIVERLESS VEHICLE STRUCK PEDESTRIAN                           8      8
# MOTOR VEHCILE STRUCK PEDESTRIAN                             6518   6485
# MOTOR VEHICLE OVERTURNED IN ROAD                             479    463
# ...

# %%
df['INCDATE'].min()
# Out:
# '2004/01/01 00:00:00+00'

# %%
df['INCDATE'].max()
# Out:
# '2020/05/20 00:00:00+00'

# %%
df['INCDATE'].sort_values()
# Out:
# 9398      2004/01/01 00:00:00+00
# 7996      2004/01/01 00:00:00+00
# 6679      2004/01/01 00:00:00+00
# 13914     2004/01/01 00:00:00+00
# 4866      2004/01/01 00:00:00+00
#                    ...
# 191912    2020/05/17 00:00:00+00
# 192328    2020/05/18 00:00:00+00
# 191908    2020/05/18 00:00:00+00
# 193070    2020/05/19 00:00:00+00
# 192030    2020/05/20 00:00:00+00
# Name: INCDATE, Length: 194673, dtype: object
